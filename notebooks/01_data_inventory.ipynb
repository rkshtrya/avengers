# %% [markdown]
# # 01 Data Inventory
#
# I use this notebook as the quick proof that the raw data is actually here and organized.

# %% [markdown]
# ![Review path](../reports/figures/review_path.svg)
#
# ![Data readiness](../reports/figures/data_readiness.svg)

# %%
import pandas as pd
summary = pd.read_csv('../reports/notebook_tables/data_inventory_summary.csv')
summary
# Out:
#                 Area                                                    Path             Current coverage                                      Status
#           SF permits data/raw/san_francisco/building_permits_selected_parts/               1,291,589 rows                                   Available
# Contra Costa parcels        data/raw/contra_costa/Parcels_Public_May2026.zip              387,835 parcels                                   Available
#    Census boundaries                                        data/raw/census/ tracts, block groups, places                                   Available
#              Schools   data/raw/schools/cde_public_schools_and_districts.txt                  18,390 rows                                   Available
#        Wildfire risk                         data/raw/risk/calfire_*.geojson             LRA/SRA extracts                                   Available
#           Flood risk                            data/raw/risk/fema_*.geojson         6,435 attribute rows Available for review; geometry join pending
#            Amenities                    data/raw/osm/osm_san_ramon_pois.json               7,026 elements                                   Available
#     Comparable sales                                            not included         needed for valuation                                     Pending
#          511 transit                                            not included             API token needed                                     Pending
#        ACS variables                                            not included        Census API key needed                                     Pending

# %% [markdown]
# ## Full File Inventory
#
# This table is long, but it is useful for checking row counts and file locations.

# %%
inventory = pd.read_csv('../reports/dataset_inventory.csv')
inventory[['path', 'kind', 'row_count', 'column_count']].head(30)
# Out:
#                                                                                         File                     Kind Rows/features  Columns
#                                             data/metadata/calfire_fhsz_catalog_metadata.json            json_metadata                    NaN
#                                                       data/metadata/calfire_fhsz_webmap.json            json_metadata                    NaN
#                                                         data/metadata/download_manifest.json            json_metadata                    NaN
#                                              data/metadata/fema_nfhl_mapserver_metadata.json            json_metadata                    NaN
#                                                            data/raw/census/tl_2025_06_bg.zip zip_shapefile_or_archive        25,607     13.0
#                                                         data/raw/census/tl_2025_06_place.zip zip_shapefile_or_archive         1,619     16.0
#                                                         data/raw/census/tl_2025_06_tract.zip zip_shapefile_or_archive         9,129     13.0
#                                                data/raw/contra_costa/BND_DCD_City_Limits.zip zip_shapefile_or_archive            20      5.0
#                                                 data/raw/contra_costa/BND_LAFCO_City_SOI.zip zip_shapefile_or_archive            19      3.0
#                                           data/raw/contra_costa/PLA_DCD_GPLanduseElement.zip zip_shapefile_or_archive         1,732      6.0
#                                                        data/raw/contra_costa/PLA_DCD_ULL.zip zip_shapefile_or_archive            18      3.0
#                                                     data/raw/contra_costa/PLA_DCD_Zoning.zip zip_shapefile_or_archive         1,259      9.0
#                                             data/raw/contra_costa/Parcels_Public_May2026.zip zip_shapefile_or_archive       387,835     10.0
#                                                         data/raw/osm/osm_san_ramon_pois.json        osm_overpass_json         7,026    339.0
#                                     data/raw/risk/calfire_fhsz_lra_contra_costa_bbox.geojson                  geojson           328      6.0
#                                     data/raw/risk/calfire_fhsz_sra_contra_costa_bbox.geojson                  geojson           241      6.0
#              data/raw/risk/fema_nfhl_flood_hazard_zones_contra_costa_bbox_attributes.geojson                  geojson         6,435     16.0
#                                                             data/raw/san_francisco/README.md                    other                    NaN
# data/raw/san_francisco/building_permits_selected_parts/building_permits_selected_part_01.csv                  tabular       175,000     30.0
# data/raw/san_francisco/building_permits_selected_parts/building_permits_selected_part_02.csv                  tabular       175,000     30.0

# %% [markdown]
# ## What Is Pending
#
# These are the items we still need to assign or unlock.

# %%
blocked = pd.read_csv('../reports/blocked_or_deferred_sources.csv')
blocked
# Out:
#                     source_id                   status                                                                                                                                           reason                                                                                                                         next_step
#          county_sales_records                  blocked                                                          No verified free automated bulk comparable-sales source for San Ramon/Contra Costa yet.                                                               Secure permitted comps source or seed 50-200 sale records manually.
#             bay_area_511_gtfs            needs_api_key                                                                                               511 GTFS and transit APIs require a 511 API token.                                         Register at 511.org, set TRANSIT_511_API_KEY, then download regional operator_id=RG feed.
# geofabrik_california_full_pbf      deferred_large_file                                                    Full California OSM PBF is about 1.3 GB. Handoff uses Overpass San Ramon POI extract instead.                Download only if team needs offline OSM processing: https://download.geofabrik.de/north-america/us/california.html
#                census_acs_5yr            needs_api_key                                                                          Current Census API requests redirect to missing_key.html without a key.                                   Set CENSUS_API_KEY and pull selected ACS variables for Contra Costa/SF tracts and block groups.
#      cde_public_districts_txt manual_download_or_retry The separate district-only endpoint returned an HTML bot-validation page in automated download. The combined schools/districts file is included. Use the included CDE schools/districts file or manually download the district-only extract from the CDE directory page if needed.
